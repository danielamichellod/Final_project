# %%
import pandas as pd
import numpy as np
import sys
sys.path.append("..")

# Paquetes de visualización
import seaborn as sns 
import matplotlib.pyplot as plt 

# Importaciones de unidades de soporte
from SRC import sp_eda, sp_visualization

# %%
aviation_df = pd.read_csv('../data/joint_dataset_cleaning.csv')
aviation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5819079 entries, 0 to 5819078
# Data columns (total 39 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   DATE                  object
#  1   YEAR                  int64
#  2   DAY                   int64
#  3   WEEKDAY               object
#  4   MONTH_NAME            object
#  5   AIRLINE_NAME          object
#  6   TAIL_NUMBER           object
#  7   FLIGHT_NUMBER         int64
#  8   SCHEDULED_DEPARTURE   object
#  9   DEPARTURE_TIME        object
#  10  DEPARTURE_DELAY       float64
#  11  TAXI_OUT              float64
#  12  WHEELS_OFF            float64
#  13  SCHEDULED_TIME        float64
#  14  SCHEDULED_TIME_HOURS  float64
#  15  ELAPSED_TIME          float64
#  16  AIR_TIME              float64
#  17  AIR_TIME_HOURS        float64
#  18  WHEELS_ON             float64
#  19  TAXI_IN               float64
#  20  ARRIVAL_TIME          object
#  21  ARRIVAL_DELAY         float64
# ...

# %%
null_count_aviation_df, null_percentage_aviation_df = sp_eda.calculate_null_percentage(aviation_df)

# %%
null_count_aviation_df
# Out:
# DATE                          0
# YEAR                          0
# DAY                           0
# WEEKDAY                       0
# MONTH_NAME                    0
# AIRLINE_NAME                  0
# TAIL_NUMBER                   0
# FLIGHT_NUMBER                 0
# SCHEDULED_DEPARTURE           0
# DEPARTURE_TIME            89884
# DEPARTURE_DELAY               0
# TAXI_OUT                      0
# WHEELS_OFF                    0
# SCHEDULED_TIME                0
# SCHEDULED_TIME_HOURS          0
# ELAPSED_TIME              89884
# AIR_TIME                  89884
# AIR_TIME_HOURS            89884
# WHEELS_ON                 89884
# TAXI_IN                   89884
# ARRIVAL_TIME             105071
# ARRIVAL_DELAY            105071
# DELAYED                  105071
# EXTREME_DELAY            105071
# CANCELLED                     0
# DIVERTED                      0
# CANCELLATION_REASON     5729195
# AIR_SYSTEM_DELAY              0
# SECURITY_DELAY                0
# ...

# %%
null_percentage_aviation_df

# The 1.54% / 1.81% nulls in time-related columns are expected because they correspond to cancelled or diverted flights so it's logically consistent.
# The 98.46% in 'CANCELLATION_REASON' also makes sense because only cancelled flights should have a cancellation reason.
# Out:
# DATE                     0.00
# YEAR                     0.00
# DAY                      0.00
# WEEKDAY                  0.00
# MONTH_NAME               0.00
# AIRLINE_NAME             0.00
# TAIL_NUMBER              0.00
# FLIGHT_NUMBER            0.00
# SCHEDULED_DEPARTURE      0.00
# DEPARTURE_TIME           1.54
# DEPARTURE_DELAY          0.00
# TAXI_OUT                 0.00
# WHEELS_OFF               0.00
# SCHEDULED_TIME           0.00
# SCHEDULED_TIME_HOURS     0.00
# ELAPSED_TIME             1.54
# AIR_TIME                 1.54
# AIR_TIME_HOURS           1.54
# WHEELS_ON                1.54
# TAXI_IN                  1.54
# ARRIVAL_TIME             1.81
# ARRIVAL_DELAY            1.81
# DELAYED                  1.81
# EXTREME_DELAY            1.81
# CANCELLED                0.00
# DIVERTED                 0.00
# CANCELLATION_REASON     98.46
# AIR_SYSTEM_DELAY         0.00
# SECURITY_DELAY           0.00
# AIRLINE_DELAY            0.00
# LATE_AIRCRAFT_DELAY      0.00
# ...

# %%
sp_eda.general_categorical_analysis(aviation_df)
# Out:
# Distribution of column DATE
# This column has 365 unique values
# DATE
# 2015-11-29    0.003020
# 2015-08-07    0.003010
# 2015-06-26    0.003003
# 2015-07-24    0.003003
# 2015-07-10    0.003002
#                 ...
# 2015-01-17    0.002074
# 2015-01-31    0.002069
# 2015-09-05    0.002060
# 2015-10-31    0.002012
# 2015-11-26    0.001730
# Name: proportion, Length: 365, dtype: float64
# ______________
# count        5819079
# unique           365
# top       2015-11-29
# freq           17574
# Name: DATE, dtype: object
# --------------
# Distribution of column WEEKDAY
# This column has 7 unique values
# WEEKDAY
# Thursday     0.149941
# Monday       0.148742
# Friday       0.148169
# Wednesday    0.147085
# Tuesday      0.145143
# Sunday       0.140532
# Saturday     0.120388
# Name: proportion, dtype: float64
# ______________
# count      5819079
# unique           7
# top       Thursday
# freq        872521
# Name: WEEKDAY, dtype: object
# --------------
# ...

# %%
sp_visualization.subplot_categorical_columns_top(aviation_df)
# Out:
# /Users/daniela/Desktop/Final_project/jupyters_notebook/../SRC/sp_visualization.py:46: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(
# /Users/daniela/Desktop/Final_project/jupyters_notebook/../SRC/sp_visualization.py:46: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(
# /Users/daniela/Desktop/Final_project/jupyters_notebook/../SRC/sp_visualization.py:46: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(
# /Users/daniela/Desktop/Final_project/jupyters_notebook/../SRC/sp_visualization.py:46: FutureWarning:
#
# ...

# %%
# Saving the aviation dataframe in the data carpet

aviation_df.to_csv('../data/joint_dataset_cleaning.csv', index=False)
