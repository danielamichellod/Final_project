# %%
# Importations

import pandas as pd 
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import sys
sys.path.append("../SRC")

import sp_cleaning_aviation as sp

pd.set_option("display.max_columns", None)

# %%
final_df = pd.read_csv('../data/joint_dataset.csv')
# Out:
# /var/folders/r8/sbs1vswj5qb9kjwlkhpfxj4c0000gn/T/ipykernel_9967/1970956837.py:1: DtypeWarning: Columns (7,8,33,34,35,36,37,40,41,42,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   final_df = pd.read_csv('../data/joint_dataset.csv')

# %%
# A copy of the joint dataset is created to implement the changes

aviation_df = final_df.copy()

# %%
sp.preliminary_eda(aviation_df)
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE_x  FLIGHT_NUMBER TAIL_NUMBER  \
# 4902096  2015     11    2            1        B6           1444      N615JB
# 2552997  2015      6   10            3        US           2020      N971UY
# 1249524  2015      3   22            7        DL           2658      N895AT
# 4486433  2015     10    7            3        DL           2792      N717JL
# 633255   2015      2   11            3        F9           1062      N211FR
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  \
# 4902096            PBI                 EWR                 1941
# 2552997            PHX                 CLT                 2300
# 1249524            DAL                 ATL                 1547
# 4486433          12478               13204                 1130
# 633255             SLC                 ORD                 1850
#
#          DEPARTURE_TIME  DEPARTURE_DELAY  TAXI_OUT  WHEELS_OFF  \
# 4902096          2025.0             44.0      16.0      2041.0
# 2552997          2325.0             25.0      12.0      2337.0
# 1249524          1549.0              2.0      15.0      1604.0
# 4486433          1119.0            -11.0      17.0      1136.0
# 633255           1913.0             23.0      12.0      1925.0
#
#          SCHEDULED_TIME  ELAPSED_TIME  AIR_TIME  DISTANCE  WHEELS_ON  TAXI_IN  \
# 4902096           168.0         170.0     146.0      1023     2307.0      8.0
# 2552997           240.0         233.0     211.0      1773      608.0     10.0
# 1249524           123.0         116.0      93.0       721     1837.0      8.0
# 4486433           165.0         147.0     124.0       944     1340.0      6.0
# 633255            185.0         180.0     159.0      1250     2304.0      9.0
#
#          SCHEDULED_ARRIVAL  ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED  \
# 4902096               2229        2315.0           46.0         0          0
# 2552997                600         618.0           18.0         0          0
# 1249524               1850        1845.0           -5.0         0          0
# 4486433               1415        1346.0          -29.0         0          0
# 633255                2255        2313.0           18.0         0          0
#
#         CANCELLATION_REASON  AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  \
# 4902096                 NaN              43.0             0.0            0.0
# 2552997                 NaN               0.0             0.0           12.0
# 1249524                 NaN               NaN             NaN            NaN
# 4486433                 NaN               NaN             NaN            NaN
# 633255                  NaN               0.0             0.0            0.0
#
#          LATE_AIRCRAFT_DELAY  WEATHER_DELAY IATA_CODE            AIRLINE_NAME  \
# 4902096                  3.0            0.0        B6         JetBlue Airways
# 2552997                  6.0            0.0        US         US Airways Inc.
# 1249524                  NaN            NaN        DL    Delta Air Lines Inc.
# 4486433                  NaN            NaN        DL    Delta Air Lines Inc.
# 633255                  18.0            0.0        F9  Frontier Airlines Inc.
#
#         IATA_CODE_ORIGIN                                   AIRPORT  \
# 4902096              PBI          Palm Beach International Airport
# 2552997              PHX  Phoenix Sky Harbor International Airport
# 1249524              DAL                         Dallas Love Field
# 4486433              NaN                                       NaN
# 633255               SLC      Salt Lake City International Airport
#
#                     CITY STATE COUNTRY  LATITUDE  LONGITUDE IATA_CODE_DEST  \
# 4902096  West Palm Beach    FL     USA  26.68316  -80.09559            EWR
# 2552997          Phoenix    AZ     USA  33.43417 -112.00806            CLT
# 1249524           Dallas    TX     USA  32.84711  -96.85177            ATL
# 4486433              NaN   NaN     NaN       NaN        NaN            NaN
# 633255    Salt Lake City    UT     USA  40.78839 -111.97777            ORD
#
#                                              AIRPORT_DEST  CITY_DEST  \
# 4902096              Newark Liberty International Airport     Newark
# 2552997           Charlotte Douglas International Airport  Charlotte
# 1249524  Hartsfield-Jackson Atlanta International Airport    Atlanta
# 4486433                                               NaN        NaN
# 633255               Chicago O'Hare International Airport    Chicago
#
#         STATE_DEST COUNTRY_DEST  LATITUDE_DEST  LONGITUDE_DEST
# 4902096         NJ          USA       40.69250       -74.16866
# 2552997         NC          USA       35.21401       -80.94313
# 1249524         GA          USA       33.64044       -84.42694
# 4486433        NaN          NaN            NaN             NaN
# 633255          IL          USA       41.97960       -87.90446
# ----------------
# INFO
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5819079 entries, 0 to 5819078
# Data columns (total 47 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   YEAR                 int64
#  1   MONTH                int64
#  2   DAY                  int64
#  3   DAY_OF_WEEK          int64
#  4   AIRLINE_x            object
#  5   FLIGHT_NUMBER        int64
#  6   TAIL_NUMBER          object
#  7   ORIGIN_AIRPORT       object
#  8   DESTINATION_AIRPORT  object
#  9   SCHEDULED_DEPARTURE  int64
#  10  DEPARTURE_TIME       float64
#  11  DEPARTURE_DELAY      float64
#  12  TAXI_OUT             float64
#  13  WHEELS_OFF           float64
#  14  SCHEDULED_TIME       float64
#  15  ELAPSED_TIME         float64
#  16  AIR_TIME             float64
#  17  DISTANCE             int64
#  18  WHEELS_ON            float64
#  19  TAXI_IN              float64
#  20  SCHEDULED_ARRIVAL    int64
#  21  ARRIVAL_TIME         float64
#  22  ARRIVAL_DELAY        float64
#  23  DIVERTED             int64
#  24  CANCELLED            int64
#  25  CANCELLATION_REASON  object
#  26  AIR_SYSTEM_DELAY     float64
#  27  SECURITY_DELAY       float64
#  28  AIRLINE_DELAY        float64
#  29  LATE_AIRCRAFT_DELAY  float64
#  30  WEATHER_DELAY        float64
#  31  IATA_CODE            object
#  32  AIRLINE_NAME         object
#  33  IATA_CODE_ORIGIN     object
#  34  AIRPORT              object
#  35  CITY                 object
#  36  STATE                object
#  37  COUNTRY              object
#  38  LATITUDE             float64
#  39  LONGITUDE            float64
#  40  IATA_CODE_DEST       object
#  41  AIRPORT_DEST         object
#  42  CITY_DEST            object
#  43  STATE_DEST           object
#  44  COUNTRY_DEST         object
#  45  LATITUDE_DEST        float64
#  46  LONGITUDE_DEST       float64
# dtypes: float64(20), int64(10), object(17)
# memory usage: 2.0+ GB
# None
# ----------------
# NULOS
# YEAR                    0.00
# MONTH                   0.00
# DAY                     0.00
# DAY_OF_WEEK             0.00
# AIRLINE_x               0.00
# FLIGHT_NUMBER           0.00
# TAIL_NUMBER             0.25
# ORIGIN_AIRPORT          0.00
# DESTINATION_AIRPORT     0.00
# SCHEDULED_DEPARTURE     0.00
# DEPARTURE_TIME          1.48
# DEPARTURE_DELAY         1.48
# TAXI_OUT                1.53
# WHEELS_OFF              1.53
# SCHEDULED_TIME          0.00
# ELAPSED_TIME            1.81
# AIR_TIME                1.81
# DISTANCE                0.00
# WHEELS_ON               1.59
# TAXI_IN                 1.59
# SCHEDULED_ARRIVAL       0.00
# ARRIVAL_TIME            1.59
# ARRIVAL_DELAY           1.81
# DIVERTED                0.00
# CANCELLED               0.00
# CANCELLATION_REASON    98.46
# AIR_SYSTEM_DELAY       81.72
# SECURITY_DELAY         81.72
# AIRLINE_DELAY          81.72
# LATE_AIRCRAFT_DELAY    81.72
# WEATHER_DELAY          81.72
# IATA_CODE               0.00
# AIRLINE_NAME            0.00
# IATA_CODE_ORIGIN        8.35
# AIRPORT                 8.35
# CITY                    8.35
# STATE                   8.35
# COUNTRY                 8.35
# LATITUDE                8.43
# LONGITUDE               8.43
# IATA_CODE_DEST          8.35
# AIRPORT_DEST            8.35
# CITY_DEST               8.35
# STATE_DEST              8.35
# COUNTRY_DEST            8.35
# LATITUDE_DEST           8.43
# LONGITUDE_DEST          8.43
# dtype: float64
# ----------------
# DUPLICADOS
# 0
# ----------------
# VALUE COUNTS
# AIRLINE_x
# WN    1261855
# DL     875881
# AA     725984
# OO     588353
# EV     571977
# UA     515723
# MQ     294632
# B6     267048
# US     198715
# AS     172521
# NK     117379
# F9      90836
# HA      76272
# VX      61903
# Name: count, dtype: int64
# ---------------------------
# TAIL_NUMBER
# N480HA    3768
# N488HA    3723
# N484HA    3723
# N493HA    3585
# N478HA    3577
#           ...
# N175UA       1
# N852NW       1
# N7LBAA       1
# N7LEAA       1
# N180UA       1
# Name: count, Length: 4897, dtype: int64
# ---------------------------
# ORIGIN_AIRPORT
# ATL      346836
# ORD      285884
# DFW      239551
# DEN      196055
# LAX      194673
#           ...
# 11577         1
# 13127         1
# 12511         1
# 12177         1
# 13344         1
# Name: count, Length: 924, dtype: int64
# ---------------------------
# DESTINATION_AIRPORT
# ATL      346904
# ORD      285906
# DFW      239582
# DEN      196010
# LAX      194696
#           ...
# 15041         1
# 12177         1
# 10918         1
# 13127         1
# 10779         1
# Name: count, Length: 920, dtype: int64
# ---------------------------
# CANCELLATION_REASON
# B    48851
# A    25262
# C    15749
# D       22
# Name: count, dtype: int64
# ---------------------------
# IATA_CODE
# WN    1261855
# DL     875881
# AA     725984
# OO     588353
# EV     571977
# UA     515723
# MQ     294632
# B6     267048
# US     198715
# AS     172521
# NK     117379
# F9      90836
# HA      76272
# VX      61903
# Name: count, dtype: int64
# ---------------------------
# AIRLINE_NAME
# Southwest Airlines Co.          1261855
# Delta Air Lines Inc.             875881
# American Airlines Inc.           725984
# Skywest Airlines Inc.            588353
# Atlantic Southeast Airlines      571977
# United Air Lines Inc.            515723
# American Eagle Airlines Inc.     294632
# JetBlue Airways                  267048
# US Airways Inc.                  198715
# Alaska Airlines Inc.             172521
# Spirit Air Lines                 117379
# Frontier Airlines Inc.            90836
# Hawaiian Airlines Inc.            76272
# Virgin America                    61903
# Name: count, dtype: int64
# ---------------------------
# IATA_CODE_ORIGIN
# ATL    346836
# ORD    285884
# DFW    239551
# DEN    196055
# LAX    194673
#         ...
# HYA        83
# DLG        77
# GST        77
# AKN        63
# ITH        34
# Name: count, Length: 322, dtype: int64
# ---------------------------
# AIRPORT
# Hartsfield-Jackson Atlanta International Airport    346836
# Chicago O'Hare International Airport                285884
# Dallas/Fort Worth International Airport             239551
# Denver International Airport                        196055
# Los Angeles International Airport                   194673
#                                                      ...
# Barnstable Municipal Airport                            83
# Dillingham Airport                                      77
# Gustavus Airport                                        77
# King Salmon Airport                                     63
# Ithaca Tompkins Regional Airport                        34
# Name: count, Length: 322, dtype: int64
# ---------------------------
# CITY
# Chicago              366770
# Atlanta              346836
# Dallas-Fort Worth    239551
# Houston              198664
# Denver               196055
#                       ...
# Hyannis                  83
# Dillingham               77
# Gustavus                 77
# King Salmon              63
# Ithaca                   34
# Name: count, Length: 308, dtype: int64
# ---------------------------
# STATE
# CA    647911
# TX    631124
# FL    415586
# IL    381644
# GA    360496
# NY    246235
# CO    215451
# AZ    165469
# NC    146906
# NV    146723
# VA    138577
# MI    137033
# WA    123548
# MN    118701
# MA    109290
# NJ    108174
# PA     99995
# UT     99972
# MO     93838
# HI     91181
# MD     86079
# TN     75443
# OH     74514
# LA     65185
# OR     55620
# WI     51376
# IN     39107
# KY     36880
# AK     33300
# OK     31445
# SC     28341
# PR     26748
# AL     26482
# AR     22654
# NM     22241
# NE     20023
# CT     18799
# IA     17382
# ID     16915
# ND     16530
# MT     14848
# MS     13109
# RI     11058
# KS     10966
# SD      9267
# WY      8218
# NH      6292
# VI      5287
# ME      5047
# VT      2978
# WV      2385
# GU       334
# AS       107
# DE       100
# Name: count, dtype: int64
# ---------------------------
# COUNTRY
# USA    5332914
# Name: count, dtype: int64
# ---------------------------
# IATA_CODE_DEST
# ATL    346904
# ORD    285906
# DFW    239582
# DEN    196010
# LAX    194696
#         ...
# STC        82
# DLG        77
# GST        77
# AKN        63
# ITH        35
# Name: count, Length: 322, dtype: int64
# ---------------------------
# AIRPORT_DEST
# Hartsfield-Jackson Atlanta International Airport    346904
# Chicago O'Hare International Airport                285906
# Dallas/Fort Worth International Airport             239582
# Denver International Airport                        196010
# Los Angeles International Airport                   194696
#                                                      ...
# St. Cloud Regional Airport                              82
# Dillingham Airport                                      77
# Gustavus Airport                                        77
# King Salmon Airport                                     63
# Ithaca Tompkins Regional Airport                        35
# Name: count, Length: 322, dtype: int64
# ---------------------------
# CITY_DEST
# Chicago              366790
# Atlanta              346904
# Dallas-Fort Worth    239582
# Houston              198724
# Denver               196010
#                       ...
# St Cloud                 82
# Dillingham               77
# Gustavus                 77
# King Salmon              63
# Ithaca                   35
# Name: count, Length: 308, dtype: int64
# ---------------------------
# STATE_DEST
# CA    647899
# TX    631214
# FL    415554
# IL    381666
# GA    360563
# NY    246231
# CO    215404
# AZ    165466
# NC    146906
# NV    146739
# VA    138558
# MI    136928
# WA    123557
# MN    118713
# MA    109299
# NJ    108237
# PA    100000
# UT     99955
# MO     93828
# HI     91176
# MD     86085
# TN     75434
# OH     74494
# LA     65184
# OR     55611
# WI     51381
# IN     39104
# KY     36874
# AK     33299
# OK     31447
# SC     28339
# PR     26747
# AL     26484
# AR     22647
# NM     22234
# NE     20023
# CT     18797
# IA     17387
# ID     16918
# ND     16535
# MT     14852
# MS     13110
# RI     11059
# KS     10966
# SD      9269
# WY      8214
# NH      6292
# VI      5286
# ME      5048
# VT      2976
# WV      2386
# GU       334
# AS       107
# DE        98
# Name: count, dtype: int64
# ---------------------------
# COUNTRY_DEST
# USA    5332914
# Name: count, dtype: int64
# ---------------------------

# %%
sp.lowercase_values(aviation_df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 sp.lowercase_values(aviation_df)
#
# AttributeError: module 'sp_cleaning_aviation' has no attribute 'lowercase_values'
